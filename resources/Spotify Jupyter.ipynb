# %%
# Import Dependencies and Spotipy App

from dateutil.parser import parse as parse_date
import pandas as pd
import spotipy
import spotipy as sp
import spotipy.util as util
import requests
from pprint import pprint
import time

user_id = '1221063701'
client_id = 'a4a8320b97e84b88bc8f4585251085ce'
client_secret = '57f7dc998a714c61b8391858bdc5cc7c'
playlist_id = '0fCFwL8LJE99raQb1g2YvF?si=27hJGryaRnWlTRCZ-UMKnw'
redirect_uri='https://www.facebook.com/groups/1223037501082162'


token = util.prompt_for_user_token(user_id,
                                   'playlist-read-collaborative',
                                   client_id,
                                   client_secret,
                                   redirect_uri)
sp = spotipy.Spotify(auth=token)

# %%
#Read Playlist to pull data from Spotify API
playlist = sp.user_playlist(user_id, playlist_id)
tracks = playlist['tracks']['items']
next_uri = playlist['tracks']['next']
for _ in range(int(playlist['tracks']['total'] / playlist['tracks']['limit'])):
    response = sp._get(next_uri)
    tracks += response['items']
    next_uri = response['next']

tracks_df = pd.DataFrame([(track['track']['id'],
                           track['track']['artists'][0]['name'],
                           track['track']['name'],
                           track['track']['artists'][0]['id'],
                           track['added_by']['id'],
                           parse_date(track['track']['album']['release_date']) if track['track']['album']['release_date'] else None,
                           parse_date(track['added_at']))
                          for track in playlist['tracks']['items']],
                         columns=['id', 'artist', 'name', 'artist_id','user_id', 'release_date', 'added_at'])

# %%
# pprint(playlist)

# %%
# Artist ID in Dataframe

artist_id = tracks_df['artist_id']
artist_id = artist_id.unique()
artist_id
# Out:
# array(['1LZEQNv7sE11VDY3SdxQeN', '08GQAI4eElDnROBrJRGE0X',
#        '45SvvyIXX9VnwpOlWrKtgT', '7gXb99Sf9nNmpNYeAgIQFG',
#        '71yUgAEgyT66SuoDHKFNwh', '4gOc8TsQed9eqnqJct2c5v',
#        '6jTnHxhb6cDCaCu4rdvsQ0', '1Qp56T7n950O3EGMsSl81D',
#        '25oLRSUjJk4YHNUsQXk7Ut', '1GAS0rb4L8VTPvizAx2O9J',
#        '00dwwnz3V4kRfu3UFYpJLz', '3vDpQbGnzRbRVirXlfQagB',
#        '1dfeR4HaWDbWqFHLkxsg1d', '3qm84nBOXUEQ2vnTfUTTFC',
#        '2W8yFh0Ga6Yf3jiayVxwkE', '5Zmur9D9gpr6tXyDrpnbOe',
#        '7ENzCHnmJUr20nUjoZ0zZ1', '7pXu47GoqSYRajmBCjxdD6',
#        '09hVIj6vWgoCDtT03h8ZCa', '1G9G7WwrXka3Z1r7aIDjI7',
#        '2ZfHMUPrxoZNDTBPHmmdhj', '7mQilAy42MqNPqUFqK4Z0o',
#        '3HJIB8sYPyxrFGuwvKXSLR', '6PJ1lXTD3zLPgo7i8NPaw9',
#        '4Z8W4fKeB5YxbusRsdQVPb', '5RzjqfPS0Bu4bUMkyNNDpn',
#        '0IK6TvlarNMoBZ7KdyjZIf', '0jOs0wnXCu1bGGP7kh5uIu',
#        '3u1ulLq00Y3bfmq9FfjsPu', '0dfkF1i9s8ZyOAKbV572T7',
#        '1Y5gloak4SGiFKEyVQYw8r', '3HQyFCFFfJO3KKBlUfZsyW',
#        '78SHxLdtysAXgywQ4vE0Oa', '1lOQRP0UJWmpoDWBa8PB0B',
#        '1YEGETLT2p8k97LIo3deHL', '242iqFnwNhlidVBMI9GYKp',
#        '1zK4ACgLi1lVPpfmmcwOTh', '0jJNGWrpjGIHUdTTJiIYeB',
#        '0zOcE3mg9nS6l3yxt1Y0bK', '4KV8ACcPuT3Jyx9Bvh6OFs',
#        '6roFdX1y5BYSbp60OTJWMd', '2QsynagSdAqZj3U9HgDzjD',
#        '4MVyzYMgTwdP7Z49wAZHx0', '3nnQpaTvKb5jCQabZefACI',
#        '4IWBUUAFIplrNtaOHcJPRM', '4GNC7GD6oZMSxPGyXy4MNB',
#        '7KMqksf0UMdyA0UCf4R3ux', '4hcWMDrWJYyU66HA583nCb',
#        '7CQwac16i1W5ej8YpuL3dv', '74cb3MG0x0BOnYNW1uXYnM',
#        '35fFUv2850L9CQjjNrLBpb', '4ogvuDRerGhZfSf7TtzHlr',
#        '4KMMjF738dOUpmO51lMUrf', '0Inhlz2EUVxsxjhdqNJY8F',
#        '3TOqt5oJwL9BE2NG9MEwDa', '4YgACLaoEjPl4kVZ5WmBN9',
#        '196lKsA13K3keVXMDFK66q', '1w5Kfo2jwwIPruYS2UWh56',
#        '0iHb0mCbqZTYeb4y9Pirrd', '3T0CG1MKkAu9rxA2ezgyLC',
#        '6kACVPfCOnqzgfEF5ryl0x', '7K78lVZ8XzkjfRSI7570FF',
#        '7H55rcKCfwqkyDFH9wpKM6', '7C4sUpWGlTy7IANjruj02I',
#        '5xKp3UyavIBUsGy3DQdXeF', '5dbuFbrHa1SJlQhQX9OUJ2',
#        '0ECwFtbIWEVNwjlrfc6xoL', '2ICSjfBpos9PxMhGhX25N2',
#        '0oSGxfWSnnOXhD2fKuz2Gy', '2x9SpqnPi8rlE9pjHBwmSC',
#        '3v4feUQnU3VEUqFrjmtekL', '6J7biCazzYhU3gM9j1wfid',
#        '3AA28KZvwAUcZuOKwyblJQ', '2feDdbD5araYcm6JhFHHw7',
#        '5BYuBzqmTXwUDw2rYkwExr', '3VNITwohbvU5Wuy5PC6dsI',
#        '4N8BwYTEC6XqykGvXXlmfv', '2W8UTum7bU7ue6m0r14H97',
#        '0KMLfCXYb3Dhf1hLpu8cVd', '2Hg4SUNDuIn8xIidz9GxFw'], dtype=object)

# %%
# Code to pull artist genre data for user ID

artist =[]
genre_info = []

artist_genres = sp.artists(artist_id)
pprint(artist_genres)

artist_genres = artist_genres['artists']

for i in range(len(artist_genres)):
    print(artist_genres[i]['name'])

    if len(artist_genres[i]['genres'])>0:
        artist.append(artist_genres[i]['name'])
        genre_info.append(artist_genres[i]['genres'][0])
              
        print(artist_genres[i]['genres'][0])
        print()
        
genre_df = pd.DataFrame({'artist': artist, 'genre' : genre_info})


# Breakup Playlist or
# Out:
# HTTP Error for GET to https://api.spotify.com/v1
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-20-a9f0dfb720bc> in <module>
#       4 genre_info = []
#       5
# ----> 6 artist_genres = sp.artists(artist_id)
#       7 pprint(artist_genres)
#       8
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in artists(self, artists)
#     367
#     368         tlist = [self._get_id("artist", a) for a in artists]
# --> 369         return self._get("artists/?ids=" + ",".join(tlist))
#     370
#     371     def artist_albums(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     259                          method, url, response.status_code, msg)
#     260
# --> 261             raise SpotifyException(
#     262                 response.status_code,
#     263                 -1,
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/artists/?ids=1LZEQNv7sE11VDY3SdxQeN,08GQAI4eElDnROBrJRGE0X,45SvvyIXX9VnwpOlWrKtgT,7gXb99Sf9nNmpNYeAgIQFG,71yUgAEgyT66SuoDHKFNwh,4gOc8TsQed9eqnqJct2c5v,6jTnHxhb6cDCaCu4rdvsQ0,1Qp56T7n950O3EGMsSl81D,25oLRSUjJk4YHNUsQXk7Ut,1GAS0rb4L8VTPvizAx2O9J,00dwwnz3V4kRfu3UFYpJLz,3vDpQbGnzRbRVirXlfQagB,1dfeR4HaWDbWqFHLkxsg1d,3qm84nBOXUEQ2vnTfUTTFC,2W8yFh0Ga6Yf3jiayVxwkE,5Zmur9D9gpr6tXyDrpnbOe,7ENzCHnmJUr20nUjoZ0zZ1,7pXu47GoqSYRajmBCjxdD6,09hVIj6vWgoCDtT03h8ZCa,1G9G7WwrXka3Z1r7aIDjI7,2ZfHMUPrxoZNDTBPHmmdhj,7mQilAy42MqNPqUFqK4Z0o,3HJIB8sYPyxrFGuwvKXSLR,6PJ1lXTD3zLPgo7i8NPaw9,4Z8W4fKeB5YxbusRsdQVPb,5RzjqfPS0Bu4bUMkyNNDpn,0IK6TvlarNMoBZ7KdyjZIf,0jOs0wnXCu1bGGP7kh5uIu,3u1ulLq00Y3bfmq9FfjsPu,0dfkF1i9s8ZyOAKbV572T7,1Y5gloak4SGiFKEyVQYw8r,3HQyFCFFfJO3KKBlUfZsyW,5q4eLKmqFVP0xII8087PHz,2gFsmDBM0hkoZPmrO5EdyO,6zvul52xwTWzilBZl6BUbT,2jlWF9ltd8UtoaqW0PxY4z,2p8trEjUiEIXGKbT5n41C1,23ymPLjbtAMzTJS2qRtQ8Z,1gWjcmBsveEYMxOZ0VRi32,74IIqlVQQmvf04EHOI6yKh,4oHlxCDDYRhEVcO4DXtAu2,7toVzxZQU21OjB5PqXNvTF,1uQWmt1OhuHGRKmZ2ZcL6p,64mPnRMMeudAet0E62ypkx,2CIMQHirSU0MQqyYHq0eOx,0X2BH1fck6amBIoJhDVmmJ,2jw70GZXlAI8QzWeY2bgRc,3QryVD03gGZOLQQXjy3EoA,6ok7bEDf9CZ0448D59AaNL,5upLeyz8OjRZcbFuXOF59B,26VFTg2z8YR0cCuwLzESi2,1wgY8huggK60P5nvYrwcYT,065LNvUlW
MKkAu9rxA2ezgyLC,6kACVPfCOnqzgfEF5ryl0x,7K78lVZ8XzkjfRSI7570FF,7H55rcKCfwqkyDFH9wpKM6,7C4sUpWGlTy7IANjruj02I,5xKp3UyavIBUsGy3DQdXeF,5dbuFbrHa1SJlQhQX9OUJ2,0ECwFtbIWEVNwjlrfc6xoL,2ICSjfBpos9PxMhGhX25N2,0oSGxfWSnnOXhD2fKuz2Gy,2x9SpqnPi8rlE9pjHBwmSC,3v4feUQnU3VEUqFrjmtekL,6J7biCazzYhU3gM9j1wfid,3AA28KZvwAUcZuOKwyblJQ,2feDdbD5araYcm6JhFHHw7,5BYuBzqmTXwUDw2rYkwExr,3VNITwohbvU5Wuy5PC6dsI,4N8BwYTEC6XqykGvXXlmfv,2W8UTum7bU7ue6m0r14H97,0KMLfCXYb3Dhf1hLpu8cVd,2Hg4SUNDuIn8xIidz9GxFw:
#  too many ids requested, reason: None

# %%
# Code to pull artist genre data for user ID

artist =[]
genre_info = []

for n in range(0,len(artist_id)):
    temp_genre = artist_id[n:n+5]
    artist_genres = sp.artists(temp_genre)

    artist_genres = artist_genres['artists']
    
    if len(artist_genres[i]['genres'])>0:
        artist.append(artist_genres[i]['name'])
        genre_info.append(artist_genres[i]['genres'][0])
              
#         print(artist_genres[i]['genres'][0])
        
genre_df = pd.DataFrame({'artist': artist, 'genre' : genre_info})
# Out:
# disco
# album rock
# chicano punk
# modern indie pop
# k-pop girl group
# dance pop
# hard rock
# edm
# alternative hip hop
# alternative americana
# classic rock
# glam metal
# post-teen pop
# jam band
# contemporary jazz
# ann arbor indie
# alternative hip hop
# atl hip hop
# jam band
# jam band
# alternative dance
# alternative rock
# bebop
# comic
# bossa nova
# alternative rock
# disney
# afrobeat
# blues rock
# alternative rock
# canadian indigenous
# japanese psychedelic rock
# alternative dance
# dancehall
# comic
# christian alternative rock
# american post-rock
# alternative metal
# canadian electronic
# dance pop
# canadian latin
# brostep
# tulsa indie
# hollywood
# dance pop
# alternative hip hop
# jam band
# alternative r&b
# australian indie rock
# pop rock
# classic italian pop
# alternative rock
# alternative rock
# pop punk
# jamgrass
# jamgrass
# belly dance
# livetronica
# adult standards
# conscious hip hop
# alternative rock
# funk
# detskie pesni
# chillhop
# electro
# german soundtrack
# chicago soul
# russian dance pop
# australian dance
# meme rap
# gypsy punk
# alternative rock
# folk metal
# alternative metal
# hard bass
# alternative rock
# permanent wave
# alternative metal
# hard rock
# album rock
# adult standards
# african rock
# classic rock
# glam rock
# irish rock
# album rock
# dance rock
# alternative metal
# alternative metal
# jam band
# canadian rock
# pop rock
# ccm
# alternative rock
# neo mellow
# contemporary country
# reggae
# album rock
# art rock
# pop
# pop
# neo mellow
# hollywood
# neo mellow
# ccm
# modern folk rock
# hawaiian
# broadway
# alternative metal
# bluegrass
# indie folk
# alternative rock
# alternative metal
# outlaw country
# arkansas country
# latin pop
# dance pop
# album rock
# indiecoustica
# album rock
# album rock
# lilith
# art rock
# art punk
# album rock
# dance pop
# alternative hip hop
# indie poptimism
# alternative dance
# disco
# adult standards
# classic soul
# disco
# contemporary jazz

# %%
genre_df['artist']
# Out:
# 0                    Bee Gees
# 1               Fleetwood Mac
# 2                  Viernes 13
# 3                   Sub Urban
# 4                        K/DA
#                 ...
# 129           Kool & The Gang
# 130             George Benson
# 131             The Dramatics
# 132             Midnight Star
# 133    Medeski, Martin & Wood
# Name: artist, Length: 134, dtype: object

# %%
genre_df = genre_df.drop_duplicates()
genre_df
# Out:
#                      artist              genre
# 0                  Bee Gees              disco
# 1             Fleetwood Mac         album rock
# 2                Viernes 13       chicano punk
# 3                 Sub Urban   modern indie pop
# 4                      K/DA   k-pop girl group
# ..                      ...                ...
# 129         Kool & The Gang              disco
# 130           George Benson    adult standards
# 131           The Dramatics       classic soul
# 132           Midnight Star              disco
# 133  Medeski, Martin & Wood  contemporary jazz
#
# [134 rows x 2 columns]

# %%
tracks_df
# Out:
#                          id                  artist  \
# 0    2cX2coZS1PYBfPs8wgbdWE                Bee Gees
# 1    0ofHAoxe9vBkTCp2UQIavz           Fleetwood Mac
# 2    1tzcIjBCwsn4P7D0OsBiFi              Viernes 13
# 3    1y4jsQt7MjnZhiD1L6qFBC               Sub Urban
# 4    34xLCJSfCdBPcPxZTRezwS                   Ray-X
# ..                      ...                     ...
# 158  4yKZACkuudvfd600H2dQie         Kool & The Gang
# 159  1m3BAsNsQAaSNMD2M6vlKY           George Benson
# 160  5lYpHO6ZO4Shys3GD8rav6           The Dramatics
# 161  3JLcx6VISiIx3Y30XPQ4K9           Midnight Star
# 162  0NMpJoxykO6UIIXxg8im8K  Medeski, Martin & Wood
#
#                                                   name  \
# 0    More Than A Woman - From "Saturday Night Fever...
# 1                               Dreams - 2004 Remaster
# 2                                        The Lucky One
# 3                                              Cradles
# 4                                Dancing Is What to Do
# ..                                                 ...
# 158                                     Get Down On It
# 159                                           Breezin'
# 160                         Whatcha See Is Whatcha Get
# 161        No Parking (On the Dance Floor) - Radio Mix
# 162                                          Chubb Sub
#
#                   artist_id     user_id release_date                  added_at
# 0    1LZEQNv7sE11VDY3SdxQeN  1221063701   2020-11-20 2021-01-13 18:21:29+00:00
# 1    08GQAI4eElDnROBrJRGE0X  1221063701   1977-02-04 2021-01-14 01:31:07+00:00
# 2    45SvvyIXX9VnwpOlWrKtgT  1221063701   2015-01-13 2021-01-21 04:40:24+00:00
# 3    7gXb99Sf9nNmpNYeAgIQFG  1213961138   2019-01-04 2021-01-21 05:23:14+00:00
# 4    71yUgAEgyT66SuoDHKFNwh  1213961138   2019-05-21 2021-01-21 05:23:17+00:00
# ..                      ...         ...          ...                       ...
# 158  3VNITwohbvU5Wuy5PC6dsI  kukulski.2   1999-03-01 2021-02-02 21:30:06+00:00
# 159  4N8BwYTEC6XqykGvXXlmfv  kukulski.2   1976-03-03 2021-02-02 21:30:24+00:00
# 160  2W8UTum7bU7ue6m0r14H97  kukulski.2   2007-01-01 2021-02-03 03:25:05+00:00
# 161  0KMLfCXYb3Dhf1hLpu8cVd  1221063701   1983-01-01 2021-02-04 04:15:24+00:00
# 162  2Hg4SUNDuIn8xIidz9GxFw  kukulski.2   2000-04-28 2021-02-10 17:04:06+00:00
#
# [163 rows x 7 columns]

# %%
user_id = tracks_df['user_id'].unique()
user_id.tolist()
# Out:
# ['1221063701',
#  '1213961138',
#  'kukulski.2',
#  '1256631666',
#  '1239315253',
#  '5x3jsdd20gyv86pg2naw63zwp']

# %%
user_song_ids = pd.DataFrame(tracks_df, columns= ['id', 'user_id'])
user_song_ids
# Out:
#                          id     user_id
# 0    2cX2coZS1PYBfPs8wgbdWE  1221063701
# 1    0ofHAoxe9vBkTCp2UQIavz  1221063701
# 2    1tzcIjBCwsn4P7D0OsBiFi  1221063701
# 3    1y4jsQt7MjnZhiD1L6qFBC  1213961138
# 4    34xLCJSfCdBPcPxZTRezwS  1213961138
# ..                      ...         ...
# 157  3DofXqoNWqAnzNpSXtSp4R  1221063701
# 158  4yKZACkuudvfd600H2dQie  kukulski.2
# 159  1m3BAsNsQAaSNMD2M6vlKY  kukulski.2
# 160  5lYpHO6ZO4Shys3GD8rav6  kukulski.2
# 161  3JLcx6VISiIx3Y30XPQ4K9  1221063701
#
# [162 rows x 2 columns]

# %%
user_artist_id = pd.DataFrame(tracks_df, columns= ['artist_id', 'user_id'])
user_artist_id
# Out:
#                   artist_id     user_id
# 0    1LZEQNv7sE11VDY3SdxQeN  1221063701
# 1    08GQAI4eElDnROBrJRGE0X  1221063701
# 2    45SvvyIXX9VnwpOlWrKtgT  1221063701
# 3    7gXb99Sf9nNmpNYeAgIQFG  1213961138
# 4    71yUgAEgyT66SuoDHKFNwh  1213961138
# ..                      ...         ...
# 157  5BYuBzqmTXwUDw2rYkwExr  1221063701
# 158  3VNITwohbvU5Wuy5PC6dsI  kukulski.2
# 159  4N8BwYTEC6XqykGvXXlmfv  kukulski.2
# 160  2W8UTum7bU7ue6m0r14H97  kukulski.2
# 161  0KMLfCXYb3Dhf1hLpu8cVd  1221063701
#
# [162 rows x 2 columns]

# %%
# Artist IDs by Users to run For Loop

charles = user_artist_id.loc[user_artist_id['user_id'] == '1221063701']
charles = charles['artist_id']

# %%
tempest = user_artist_id.loc[user_artist_id['user_id'] == '1213961138']
tempest = tempest['artist_id']

# %%
matt = user_artist_id.loc[user_artist_id['user_id'] == 'kukulski.2']
matt = matt['artist_id']

# %%
stu = user_artist_id.loc[user_artist_id['user_id'] == '1256631666']
stu = stu['artist_id']

# %%
john = user_artist_id.loc[user_artist_id['user_id'] == '1239315253']
john = john['artist_id']

# %%
pauly = user_artist_id.loc[user_artist_id['user_id'] == '5x3jsdd20gyv86pg2naw63zwp']
pauly = pauly['artist_id']

# %%
charles.count()
# Out:
# 37

# %%
artist =[]
genre_info = []

artist_genres = sp.artists(charles)
pprint(artist_genres)

artist_genres = artist_genres['artists']

for i in range(len(artist_genres)):
    print(artist_genres[i]['name'])

    if len(artist_genres[i]['genres'])>0:
        artist.append(artist_genres[i]['name'])
        genre_info.append(artist_genres[i]['genres'][0])
              
        print(artist_genres[i]['genres'][0])
        print()
        
genre_df = pd.DataFrame({'artist': artist, 'genre' : genre_info})
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#               'followers': {'href': None, 'total': 4092666},
#               'genres': ['adult standards',
#                          'disco',
#                          'mellow gold',
#                          'soft rock'],
#               'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#               'id': '1LZEQNv7sE11VDY3SdxQeN',
#               'images': [{'height': 733,
#                           'url': 'https://i.scdn.co/image/1d5a05673975ba0c378cd280344e000b0b865620',
#                           'width': 1000},
#                          {'height': 469,
#                           'url': 'https://i.scdn.co/image/1ea4795e17ffa658d7ad23095d58997a278179a9',
#                           'width': 640},
#                          {'height': 147,
#                           'url': 'https://i.scdn.co/image/1f363042bdd59e0f80cb7b9cac1b312f9389b019',
#                           'width': 200},
#                          {'height': 47,
#                           'url': 'https://i.scdn.co/image/c707552215757c7f2dc6071e32d487a3c7b28d3f',
#                           'width': 64}],
#               'name': 'Bee Gees',
#               'popularity': 80,
#               'type': 'artist',
#               'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#               'followers': {'href': None, 'total': 5986264},
#               'genres': ['album rock',
#                          'classic rock',
#                          'mellow gold',
#                          'rock',
#                          'soft rock',
#                          'yacht rock'],
#               'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#               'id': '08GQAI4eElDnROBrJRGE0X',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/8976b6b0aacba6f7859b1f0ab7bc0adcd6ea7444',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/7316c71bf06332dc259e14ddce420b2b060e9c69',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/4f7f18a93be4af82f876ff9ce79ede8a3cecd712',
#                           'width': 160}],
#               'name': 'Fleetwood Mac',
#               'popularity': 85,
#               'type': 'artist',
#               'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/45SvvyIXX9VnwpOlWrKtgT'},
#               'followers': {'href': None, 'total': 6736},
#               'genres': ['chicano punk'],
#               'href': 'https://api.spotify.com/v1/artists/45SvvyIXX9VnwpOlWrKtgT',
#               'id': '45SvvyIXX9VnwpOlWrKtgT',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b273629fd0bc269b8b81b06be3e9',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e02629fd0bc269b8b81b06be3e9',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d00004851629fd0bc269b8b81b06be3e9',
#                           'width': 64}],
#               'name': 'Viernes 13',
#               'popularity': 22,
#               'type': 'artist',
#               'uri': 'spotify:artist:45SvvyIXX9VnwpOlWrKtgT'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/25oLRSUjJk4YHNUsQXk7Ut'},
#               'followers': {'href': None, 'total': 320756},
#               'genres': ['edm',
#                          'electronic trap',
#                          'electropop',
#                          'jamtronica',
#                          'jazztronica',
#                          'livetronica'],
#               'href': 'https://api.spotify.com/v1/artists/25oLRSUjJk4YHNUsQXk7Ut',
#               'id': '25oLRSUjJk4YHNUsQXk7Ut',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/47303c456bd258179a83ccdd52a0ab95421f628a',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/aaf49aff862a5f124bfffa78fe2c313e87042fb9',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/1a54def9b5f56aad2c41dfb43d309d14030c2b4e',
#                           'width': 160}],
#               'name': 'GRiZ',
#               'popularity': 64,
#               'type': 'artist',
#               'uri': 'spotify:artist:25oLRSUjJk4YHNUsQXk7Ut'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAS0rb4L8VTPvizAx2O9J'},
#               'followers': {'href': None, 'total': 566375},
#               'genres': ['alternative hip hop',
#                          'conscious hip hop',
#                          'minnesota hip hop',
#                          'pop rap'],
#               'href': 'https://api.spotify.com/v1/artists/1GAS0rb4L8VTPvizAx2O9J',
#               'id': '1GAS0rb4L8VTPvizAx2O9J',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/1ee427cfbf16301d708c7d36fd1bdb128a3d7f80',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/67e3cb43449a9e34b9f55cec67a0abb1fd05d247',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/7313df132b756a721a73e3d26b20ba68524560c0',
#                           'width': 160}],
#               'name': 'Atmosphere',
#               'popularity': 63,
#               'type': 'artist',
#               'uri': 'spotify:artist:1GAS0rb4L8VTPvizAx2O9J'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/00dwwnz3V4kRfu3UFYpJLz'},
#               'followers': {'href': None, 'total': 139705},
#               'genres': [],
#               'href': 'https://api.spotify.com/v1/artists/00dwwnz3V4kRfu3UFYpJLz',
#               'id': '00dwwnz3V4kRfu3UFYpJLz',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/92ab4f63f7334bcce1057d78232997f598dcaf1e',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/dfc741b0199f568da7aa42153517b72a416cdca8',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/3d63a835fff2f90c58bf56bc57f443cb14b0a8e0',
#                           'width': 160}],
#               'name': 'Cherub',
#               'popularity': 59,
#               'type': 'artist',
#               'uri': 'spotify:artist:00dwwnz3V4kRfu3UFYpJLz'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vDpQbGnzRbRVirXlfQagB'},
#               'followers': {'href': None, 'total': 475381},
#               'genres': ['alternative americana',
#                          'indie folk',
#                          'kentucky roots',
#                          'nashville singer-songwriter',
#                          'new americana',
#                          'outlaw country',
#                          'roots rock'],
#               'href': 'https://api.spotify.com/v1/artists/3vDpQbGnzRbRVirXlfQagB',
#               'id': '3vDpQbGnzRbRVirXlfQagB',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/404240e5fa61e7d5039e10f1a2b9bbbc38b42c55',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/877245820c85abeb2cf916dc4c16fe60f32812c4',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/156b882c006d5b53c5f8d11e9b1f4b688a762c8f',
#                           'width': 160}],
#               'name': 'Sturgill Simpson',
#               'popularity': 69,
#               'type': 'artist',
#               'uri': 'spotify:artist:3vDpQbGnzRbRVirXlfQagB'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#               'followers': {'href': None, 'total': 31913917},
#               'genres': ['classic rock', 'glam rock', 'rock'],
#               'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#               'id': '1dfeR4HaWDbWqFHLkxsg1d',
#               'images': [{'height': 806,
#                           'url': 'https://i.scdn.co/image/b040846ceba13c3e9c125d68389491094e7f2982',
#                           'width': 999},
#                          {'height': 516,
#                           'url': 'https://i.scdn.co/image/af2b8e57f6d7b5d43a616bd1e27ba552cd8bfd42',
#                           'width': 640},
#                          {'height': 161,
#                           'url': 'https://i.scdn.co/image/c06971e9ff81696699b829484e3be165f4e64368',
#                           'width': 200},
#                          {'height': 52,
#                           'url': 'https://i.scdn.co/image/6dd0ffd270903d1884edf9058c49f58b03db893d',
#                           'width': 64}],
#               'name': 'Queen',
#               'popularity': 89,
#               'type': 'artist',
#               'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#               'followers': {'href': None, 'total': 19411228},
#               'genres': ['glam metal', 'hard rock', 'rock'],
#               'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#               'id': '3qm84nBOXUEQ2vnTfUTTFC',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/80920b4fc80b6d970e2934eb8abe27014fc60632',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/18a0c85501ed5b614510a194bb238ac323dcc5a4',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/7fad9d837d4132de0008da41b98ce3fc29433d7e',
#                           'width': 160}],
#               'name': "Guns N' Roses",
#               'popularity': 83,
#               'type': 'artist',
#               'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8yFh0Ga6Yf3jiayVxwkE'},
#               'followers': {'href': None, 'total': 2624785},
#               'genres': ['post-teen pop', 'social media pop'],
#               'href': 'https://api.spotify.com/v1/artists/2W8yFh0Ga6Yf3jiayVxwkE',
#               'id': '2W8yFh0Ga6Yf3jiayVxwkE',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/0a0a5110d91660b149c25dbd0ecc81a2078d611f',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/235c00da3ad44c458c1262be184ddcc0c170bacb',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/caf2b1c251596cdef5a5429b3a2fc6cbc2e246a3',
#                           'width': 160}],
#               'name': 'Dove Cameron',
#               'popularity': 72,
#               'type': 'artist',
#               'uri': 'spotify:artist:2W8yFh0Ga6Yf3jiayVxwkE'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1wgY8huggK60P5nvYrwcYT'},
#               'followers': {'href': None, 'total': 224719},
#               'genres': ['indie pop rap', 'pop rap', 'rap'],
#               'href': 'https://api.spotify.com/v1/artists/1wgY8huggK60P5nvYrwcYT',
#               'id': '1wgY8huggK60P5nvYrwcYT',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/9c92b7e1a521ec280477ebd2bad1cf16eae601a2',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/b1aeea125a9bd3db5865038d9e52ef34925ee7d3',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/3023995070b26e3072f5be969146631381305310',
#                           'width': 160}],
#               'name': 'Asher Roth',
#               'popularity': 55,
#               'type': 'artist',
#               'uri': 'spotify:artist:1wgY8huggK60P5nvYrwcYT'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/065LNvUlWn6czWo7Eu3HrH'},
#               'followers': {'href': None, 'total': 15345},
#               'genres': ['jam band', 'livetronica'],
#               'href': 'https://api.spotify.com/v1/artists/065LNvUlWn6czWo7Eu3HrH',
#               'id': '065LNvUlWn6czWo7Eu3HrH',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/b6b1582221ea943363990dbb041d102b6b2f2a4e',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/1e38041aaabd6ad13ea98bb737608364721d9a56',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/b22ba7e620b76e51577fe3cc4e1fe1bd8ffe3019',
#                           'width': 160}],
#               'name': 'Zoogma',
#               'popularity': 33,
#               'type': 'artist',
#               'uri': 'spotify:artist:065LNvUlWn6czWo7Eu3HrH'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/5sKvgmG84C0bIMWeS2SRPr'},
#               'followers': {'href': None, 'total': 80270},
#               'genres': ['alternative r&b',
#                          'indie r&b',
#                          'indie soul',
#                          'nyc pop'],
#               'href': 'https://api.spotify.com/v1/artists/5sKvgmG84C0bIMWeS2SRPr',
#               'id': '5sKvgmG84C0bIMWeS2SRPr',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/dc4b5cdc59bf04d3bfb9fff1be5549419a8607ed',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/7a0a9706c37bded1c9d8b51d50a3528cb37f2702',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/4c4c117db5ae5c9018e974718669dfe6d22cbd8f',
#                           'width': 160}],
#               'name': 'Brasstracks',
#               'popularity': 57,
#               'type': 'artist',
#               'uri': 'spotify:artist:5sKvgmG84C0bIMWeS2SRPr'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/5XOV5b7cxUgB9PcoLBn69l'},
#               'followers': {'href': None, 'total': 11301},
#               'genres': ['australian indie rock'],
#               'href': 'https://api.spotify.com/v1/artists/5XOV5b7cxUgB9PcoLBn69l',
#               'id': '5XOV5b7cxUgB9PcoLBn69l',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/8840dfe29fe93e8b60ca521743a0dc7e6999a9af',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/a94bfaab8a8990c1de871e0008381dc0bbaf19d1',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/b350843723c0f025840088cd61456ce06cc5de25',
#                           'width': 160}],
#               'name': 'Eliza & The Delusionals',
#               'popularity': 40,
#               'type': 'artist',
#               'uri': 'spotify:artist:5XOV5b7cxUgB9PcoLBn69l'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/4mYFgEjpQT4IKOrjOUKyXu'},
#               'followers': {'href': None, 'total': 94358},
#               'genres': ['pop rock'],
#               'href': 'https://api.spotify.com/v1/artists/4mYFgEjpQT4IKOrjOUKyXu',
#               'id': '4mYFgEjpQT4IKOrjOUKyXu',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/4835905c5d89d488aa928d693e0b19b34020a2e1',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/5efeb10ae079cd35e28b33358515ab86feb950e6',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/82d9831f4e571a4cae9ab08eede7abe21eb812c4',
#                           'width': 160}],
#               'name': 'Wheatus',
#               'popularity': 63,
#               'type': 'artist',
#               'uri': 'spotify:artist:4mYFgEjpQT4IKOrjOUKyXu'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/00w9sdZ78mWArooTmiSTld'},
#               'followers': {'href': None, 'total': 192756},
#               'genres': ['classic italian pop', 'italian adult pop'],
#               'href': 'https://api.spotify.com/v1/artists/00w9sdZ78mWArooTmiSTld',
#               'id': '00w9sdZ78mWArooTmiSTld',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/e41fe85de7f1fcfb347869069469d2252fabdfbf',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/1362740d12bbb4a1283f5de272b598fa178e89a0',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/e08667dc1b3641fb043bddd51171828f8ba73c7c',
#                           'width': 160}],
#               'name': 'Umberto Tozzi',
#               'popularity': 61,
#               'type': 'artist',
#               'uri': 'spotify:artist:00w9sdZ78mWArooTmiSTld'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zB02lwP6L6ZH32nggQiJT'},
#               'followers': {'href': None, 'total': 267400},
#               'genres': ['alternative rock',
#                          'comic',
#                          'geek rock',
#                          'permanent wave',
#                          'zolo'],
#               'href': 'https://api.spotify.com/v1/artists/6zB02lwP6L6ZH32nggQiJT',
#               'id': '6zB02lwP6L6ZH32nggQiJT',
#               'images': [{'height': 1000,
#                           'url': 'https://i.scdn.co/image/ab6772690000c46c25ccda5d50da959ce4872f2e',
#                           'width': 1000},
#                          {'height': 640,
#                           'url': 'https://i.scdn.co/image/ab6772690000dd2225ccda5d50da959ce4872f2e',
#                           'width': 640},
#                          {'height': 200,
#                           'url': 'https://i.scdn.co/image/ab6772690000bac325ccda5d50da959ce4872f2e',
#                           'width': 200},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67726900008f7425ccda5d50da959ce4872f2e',
#                           'width': 64}],
#               'name': 'They Might Be Giants',
#               'popularity': 61,
#               'type': 'artist',
#               'uri': 'spotify:artist:6zB02lwP6L6ZH32nggQiJT'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6A43Djmhbe9100UwnI7epV'},
#               'followers': {'href': None, 'total': 821580},
#               'genres': ['alternative rock',
#                          'modern rock',
#                          'pop rock',
#                          'rock',
#                          'sacramento indie'],
#               'href': 'https://api.spotify.com/v1/artists/6A43Djmhbe9100UwnI7epV',
#               'id': '6A43Djmhbe9100UwnI7epV',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/48e3b385ab47322fde0605edcb59101efeff91c9',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/4f0adafec733359a23d2f51416b3f86f15c20532',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/1dac9f82d940e5f9f471ed6a55c990bb49367d29',
#                           'width': 160}],
#               'name': 'Cake',
#               'popularity': 66,
#               'type': 'artist',
#               'uri': 'spotify:artist:6A43Djmhbe9100UwnI7epV'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sVQKNtdP2NylxMgbNOJMM'},
#               'followers': {'href': None, 'total': 309139},
#               'genres': ['pop punk',
#                          'punk',
#                          'ska',
#                          'ska punk',
#                          'skate punk',
#                          'socal pop punk'],
#               'href': 'https://api.spotify.com/v1/artists/7sVQKNtdP2NylxMgbNOJMM',
#               'id': '7sVQKNtdP2NylxMgbNOJMM',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/d85361d5484817d9fc0a3dccfca4a5f206b16d2c',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/1f1bed1704ea0c0d03edeb0dc25264c61ec70bcd',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/bc1c4bd1b02b2b69a5028156fe1f10c037934f80',
#                           'width': 160}],
#               'name': 'Goldfinger',
#               'popularity': 63,
#               'type': 'artist',
#               'uri': 'spotify:artist:7sVQKNtdP2NylxMgbNOJMM'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sVQKNtdP2NylxMgbNOJMM'},
#               'followers': {'href': None, 'total': 309139},
#               'genres': ['pop punk',
#                          'punk',
#                          'ska',
#                          'ska punk',
#                          'skate punk',
#                          'socal pop punk'],
#               'href': 'https://api.spotify.com/v1/artists/7sVQKNtdP2NylxMgbNOJMM',
#               'id': '7sVQKNtdP2NylxMgbNOJMM',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/d85361d5484817d9fc0a3dccfca4a5f206b16d2c',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/1f1bed1704ea0c0d03edeb0dc25264c61ec70bcd',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/bc1c4bd1b02b2b69a5028156fe1f10c037934f80',
#                           'width': 160}],
#               'name': 'Goldfinger',
#               'popularity': 63,
#               'type': 'artist',
#               'uri': 'spotify:artist:7sVQKNtdP2NylxMgbNOJMM'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7rf2o0cPl8umbTCyKu1NFe'},
#               'followers': {'href': None, 'total': 1514},
#               'genres': ['jamgrass'],
#               'href': 'https://api.spotify.com/v1/artists/7rf2o0cPl8umbTCyKu1NFe',
#               'id': '7rf2o0cPl8umbTCyKu1NFe',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b2736d5744122888e43e8db4d9c8',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e026d5744122888e43e8db4d9c8',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d000048516d5744122888e43e8db4d9c8',
#                           'width': 64}],
#               'name': 'Fruition & Grant Farm',
#               'popularity': 26,
#               'type': 'artist',
#               'uri': 'spotify:artist:7rf2o0cPl8umbTCyKu1NFe'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7rf2o0cPl8umbTCyKu1NFe'},
#               'followers': {'href': None, 'total': 1514},
#               'genres': ['jamgrass'],
#               'href': 'https://api.spotify.com/v1/artists/7rf2o0cPl8umbTCyKu1NFe',
#               'id': '7rf2o0cPl8umbTCyKu1NFe',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b2736d5744122888e43e8db4d9c8',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e026d5744122888e43e8db4d9c8',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d000048516d5744122888e43e8db4d9c8',
#                           'width': 64}],
#               'name': 'Fruition & Grant Farm',
#               'popularity': 26,
#               'type': 'artist',
#               'uri': 'spotify:artist:7rf2o0cPl8umbTCyKu1NFe'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1FOvTmGxJonmXkpE2uqjB8'},
#               'followers': {'href': None, 'total': 1152},
#               'genres': ['jamgrass'],
#               'href': 'https://api.spotify.com/v1/artists/1FOvTmGxJonmXkpE2uqjB8',
#               'id': '1FOvTmGxJonmXkpE2uqjB8',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b2738853a1efc67ea30135ef8ce3',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e028853a1efc67ea30135ef8ce3',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d000048518853a1efc67ea30135ef8ce3',
#                           'width': 64}],
#               'name': 'Rapidgrass',
#               'popularity': 14,
#               'type': 'artist',
#               'uri': 'spotify:artist:1FOvTmGxJonmXkpE2uqjB8'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/30DZgkaEYdezg2QMrMgrnm'},
#               'followers': {'href': None, 'total': 160106},
#               'genres': ['belly dance', 'glitch hop', 'world fusion'],
#               'href': 'https://api.spotify.com/v1/artists/30DZgkaEYdezg2QMrMgrnm',
#               'id': '30DZgkaEYdezg2QMrMgrnm',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/56a64728771ce6aceaec104327f2a0ece1ea7b6d',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/4d2a59bf22a8ea7113888787077866cf85415307',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/a0d7f681ba75e3627fa846932320991276da713c',
#                           'width': 160}],
#               'name': 'Beats Antique',
#               'popularity': 47,
#               'type': 'artist',
#               'uri': 'spotify:artist:30DZgkaEYdezg2QMrMgrnm'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/30DZgkaEYdezg2QMrMgrnm'},
#               'followers': {'href': None, 'total': 160106},
#               'genres': ['belly dance', 'glitch hop', 'world fusion'],
#               'href': 'https://api.spotify.com/v1/artists/30DZgkaEYdezg2QMrMgrnm',
#               'id': '30DZgkaEYdezg2QMrMgrnm',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/56a64728771ce6aceaec104327f2a0ece1ea7b6d',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/4d2a59bf22a8ea7113888787077866cf85415307',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/a0d7f681ba75e3627fa846932320991276da713c',
#                           'width': 160}],
#               'name': 'Beats Antique',
#               'popularity': 47,
#               'type': 'artist',
#               'uri': 'spotify:artist:30DZgkaEYdezg2QMrMgrnm'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fVA4YnUI0DgAkfNvuDtav'},
#               'followers': {'href': None, 'total': 16279},
#               'genres': ['livetronica'],
#               'href': 'https://api.spotify.com/v1/artists/7fVA4YnUI0DgAkfNvuDtav',
#               'id': '7fVA4YnUI0DgAkfNvuDtav',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b273a7a1741560fa4f9f62dd4f58',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e02a7a1741560fa4f9f62dd4f58',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d00004851a7a1741560fa4f9f62dd4f58',
#                           'width': 64}],
#               'name': 'GRiZMATiK',
#               'popularity': 31,
#               'type': 'artist',
#               'uri': 'spotify:artist:7fVA4YnUI0DgAkfNvuDtav'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vDpQbGnzRbRVirXlfQagB'},
#               'followers': {'href': None, 'total': 475381},
#               'genres': ['alternative americana',
#                          'indie folk',
#                          'kentucky roots',
#                          'nashville singer-songwriter',
#                          'new americana',
#                          'outlaw country',
#                          'roots rock'],
#               'href': 'https://api.spotify.com/v1/artists/3vDpQbGnzRbRVirXlfQagB',
#               'id': '3vDpQbGnzRbRVirXlfQagB',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/404240e5fa61e7d5039e10f1a2b9bbbc38b42c55',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/877245820c85abeb2cf916dc4c16fe60f32812c4',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/156b882c006d5b53c5f8d11e9b1f4b688a762c8f',
#                           'width': 160}],
#               'name': 'Sturgill Simpson',
#               'popularity': 69,
#               'type': 'artist',
#               'uri': 'spotify:artist:3vDpQbGnzRbRVirXlfQagB'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Mcii5XWf6E0lrY3Uky4cA'},
#               'followers': {'href': None, 'total': 4208625},
#               'genres': ['conscious hip hop',
#                          'g funk',
#                          'gangster rap',
#                          'hardcore hip hop',
#                          'hip hop',
#                          'rap',
#                          'west coast rap'],
#               'href': 'https://api.spotify.com/v1/artists/3Mcii5XWf6E0lrY3Uky4cA',
#               'id': '3Mcii5XWf6E0lrY3Uky4cA',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/8ed73361f9c205b88c4d092b2f628576e2c719c8',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/5414f371462d8c9d5d35c1a1b908d9f2a65fefbb',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/24c863b3ebfa8848f7691a2084456cd9a7dac567',
#                           'width': 160}],
#               'name': 'Ice Cube',
#               'popularity': 76,
#               'type': 'artist',
#               'uri': 'spotify:artist:3Mcii5XWf6E0lrY3Uky4cA'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#               'followers': {'href': None, 'total': 2350659},
#               'genres': ['alternative rock',
#                          'blues rock',
#                          'detroit rock',
#                          'garage rock',
#                          'modern blues rock',
#                          'modern rock',
#                          'permanent wave',
#                          'punk blues',
#                          'rock'],
#               'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#               'id': '4F84IBURUo98rz4r61KF70',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/d09c155c272eaedd927a154a14cdf03d21680787',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/5cab623823252ff46af176146d0cc56bf5bda583',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/d38d2d986b6d7fc76a615da7d00fef6a72bac25a',
#                           'width': 160}],
#               'name': 'The White Stripes',
#               'popularity': 75,
#               'type': 'artist',
#               'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#               'followers': {'href': None, 'total': 2350659},
#               'genres': ['alternative rock',
#                          'blues rock',
#                          'detroit rock',
#                          'garage rock',
#                          'modern blues rock',
#                          'modern rock',
#                          'permanent wave',
#                          'punk blues',
#                          'rock'],
#               'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#               'id': '4F84IBURUo98rz4r61KF70',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/d09c155c272eaedd927a154a14cdf03d21680787',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/5cab623823252ff46af176146d0cc56bf5bda583',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/d38d2d986b6d7fc76a615da7d00fef6a72bac25a',
#                           'width': 160}],
#               'name': 'The White Stripes',
#               'popularity': 75,
#               'type': 'artist',
#               'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7GaxyUddsPok8BuhxN6OUW'},
#               'followers': {'href': None, 'total': 1651676},
#               'genres': ['funk', 'motown', 'soul'],
#               'href': 'https://api.spotify.com/v1/artists/7GaxyUddsPok8BuhxN6OUW',
#               'id': '7GaxyUddsPok8BuhxN6OUW',
#               'images': [{'height': 1228,
#                           'url': 'https://i.scdn.co/image/5b9eeb6ce3dcfe08218098a78565fbf214034a5e',
#                           'width': 1000},
#                          {'height': 786,
#                           'url': 'https://i.scdn.co/image/8590cf083b8ab7c1e13128e6f306a879e47ae49c',
#                           'width': 640},
#                          {'height': 246,
#                           'url': 'https://i.scdn.co/image/77e8a495845543e1a298c7c5a5d047d52ce535d9',
#                           'width': 200},
#                          {'height': 79,
#                           'url': 'https://i.scdn.co/image/d6ed5fe143dfd0e4d523d23801e528a3a4f6a5fe',
#                           'width': 64}],
#               'name': 'James Brown',
#               'popularity': 69,
#               'type': 'artist',
#               'uri': 'spotify:artist:7GaxyUddsPok8BuhxN6OUW'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6UytT10yRM4nDE6XhbjPyK'},
#               'followers': {'href': None, 'total': 913},
#               'genres': ['detskie pesni'],
#               'href': 'https://api.spotify.com/v1/artists/6UytT10yRM4nDE6XhbjPyK',
#               'id': '6UytT10yRM4nDE6XhbjPyK',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/ab67616d0000b273857f6fd5a473ccd9e62cc567',
#                           'width': 640},
#                          {'height': 300,
#                           'url': 'https://i.scdn.co/image/ab67616d00001e02857f6fd5a473ccd9e62cc567',
#                           'width': 300},
#                          {'height': 64,
#                           'url': 'https://i.scdn.co/image/ab67616d00004851857f6fd5a473ccd9e62cc567',
#                           'width': 64}],
#               'name': 'Бурёнка Даша',
#               'popularity': 36,
#               'type': 'artist',
#               'uri': 'spotify:artist:6UytT10yRM4nDE6XhbjPyK'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1PAvmfu0TKYSVVWGl3uJNC'},
#               'followers': {'href': None, 'total': 125262},
#               'genres': ['russian dance pop', 'russian pop', 'ukrainian pop'],
#               'href': 'https://api.spotify.com/v1/artists/1PAvmfu0TKYSVVWGl3uJNC',
#               'id': '1PAvmfu0TKYSVVWGl3uJNC',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/b587dd5407c5bd6dc2508a7e578a194f49da5767',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/cf5268f25edee1d2ad52660ca1521d90fc6d6c12',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/d3f7ce4b1447400180eab9e3b1563082a23baac6',
#                           'width': 160}],
#               'name': 'Yolka',
#               'popularity': 50,
#               'type': 'artist',
#               'uri': 'spotify:artist:1PAvmfu0TKYSVVWGl3uJNC'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2SVw939fwuqSobLjF8u78b'},
#               'followers': {'href': None, 'total': 264935},
#               'genres': ['gypsy punk'],
#               'href': 'https://api.spotify.com/v1/artists/2SVw939fwuqSobLjF8u78b',
#               'id': '2SVw939fwuqSobLjF8u78b',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/7849a19469393d8c1b8f49bdbc1312712c2ef131',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/8dbe4ad9e7896fdae6384bb668e5518707139ca0',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/e8eb674231ea3705e119057e8151fffd3f9a9dac',
#                           'width': 160}],
#               'name': 'Gogol Bordello',
#               'popularity': 50,
#               'type': 'artist',
#               'uri': 'spotify:artist:2SVw939fwuqSobLjF8u78b'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2CIMQHirSU0MQqyYHq0eOx'},
#               'followers': {'href': None, 'total': 2550778},
#               'genres': ['canadian electronic',
#                          'edm',
#                          'electro house',
#                          'progressive house'],
#               'href': 'https://api.spotify.com/v1/artists/2CIMQHirSU0MQqyYHq0eOx',
#               'id': '2CIMQHirSU0MQqyYHq0eOx',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/00de6379faa5c8b1006fe858cea1b2916b90352b',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/88ff724abdd8347723397d535971219d3155ad46',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/aadbfa4db66928b01332f4bc07825e2deaaf814f',
#                           'width': 160}],
#               'name': 'deadmau5',
#               'popularity': 71,
#               'type': 'artist',
#               'uri': 'spotify:artist:2CIMQHirSU0MQqyYHq0eOx'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/5BYuBzqmTXwUDw2rYkwExr'},
#               'followers': {'href': None, 'total': 544140},
#               'genres': ['alternative dance',
#                          'alternative rock',
#                          'dance-punk',
#                          'garage rock',
#                          'garage rock revival',
#                          'indie rock',
#                          'modern blues rock',
#                          'modern rock',
#                          'new rave',
#                          'punk blues',
#                          'rock'],
#               'href': 'https://api.spotify.com/v1/artists/5BYuBzqmTXwUDw2rYkwExr',
#               'id': '5BYuBzqmTXwUDw2rYkwExr',
#               'images': [{'height': 640,
#                           'url': 'https://i.scdn.co/image/e7f806051604c88068d79e19db329d9b9986fa76',
#                           'width': 640},
#                          {'height': 320,
#                           'url': 'https://i.scdn.co/image/471036f6da66b21eab65ad1fb175b456e7935d4b',
#                           'width': 320},
#                          {'height': 160,
#                           'url': 'https://i.scdn.co/image/e4223dc6f80b14832ae9658617b38b581bdab75d',
#                           'width': 160}],
#               'name': 'The Kills',
#               'popularity': 57,
#               'type': 'artist',
#               'uri': 'spotify:artist:5BYuBzqmTXwUDw2rYkwExr'},
#              {'external_urls': {'spotify': 'https://open.spotify.com/artist/0KMLfCXYb3Dhf1hLpu8cVd'},
#               'followers': {'href': None, 'total': 282935},
#               'genres': ['disco',
#                          'electro',
#                          'funk',
#                          'motown',
#                          'new jack swing',
#                          'post-disco',
#                          'quiet storm',
#                          'urban contemporary'],
#               'href': 'https://api.spotify.com/v1/artists/0KMLfCXYb3Dhf1hLpu8cVd',
#               'id': '0KMLfCXYb3Dhf1hLpu8cVd',
#               'images': [{'height': 653,
#                           'url': 'https://i.scdn.co/image/3b9bbdfad44056ca22ebd9cbbe1cd74fc7997d8a',
#                           'width': 1000},
#                          {'height': 418,
#                           'url': 'https://i.scdn.co/image/a0b7fcc225c8797b80b600ab358397ab6bf95bf2',
#                           'width': 640},
#                          {'height': 131,
#                           'url': 'https://i.scdn.co/image/abec0f3de2be797efd074d68288be68e245535e0',
#                           'width': 200},
#                          {'height': 42,
#                           'url': 'https://i.scdn.co/image/85923bcae41941f49129597ec569943fe340b851',
#                           'width': 64}],
#               'name': 'Midnight Star',
#               'popularity': 51,
#               'type': 'artist',
#               'uri': 'spotify:artist:0KMLfCXYb3Dhf1hLpu8cVd'}]}
# Bee Gees
# adult standards
#
# Fleetwood Mac
# album rock
#
# Viernes 13
# chicano punk
#
# GRiZ
# edm
#
# Atmosphere
# alternative hip hop
#
# Cherub
# Sturgill Simpson
# alternative americana
#
# Queen
# classic rock
#
# Guns N' Roses
# glam metal
#
# Dove Cameron
# post-teen pop
#
# Asher Roth
# indie pop rap
#
# Zoogma
# jam band
#
# Brasstracks
# alternative r&b
#
# Eliza & The Delusionals
# australian indie rock
#
# Wheatus
# pop rock
#
# Umberto Tozzi
# classic italian pop
#
# They Might Be Giants
# alternative rock
#
# Cake
# alternative rock
#
# Goldfinger
# pop punk
#
# Goldfinger
# pop punk
#
# Fruition & Grant Farm
# jamgrass
#
# Fruition & Grant Farm
# jamgrass
#
# Rapidgrass
# jamgrass
#
# Beats Antique
# belly dance
#
# Beats Antique
# belly dance
#
# GRiZMATiK
# livetronica
#
# Sturgill Simpson
# alternative americana
#
# Ice Cube
# conscious hip hop
#
# The White Stripes
# alternative rock
#
# The White Stripes
# alternative rock
#
# James Brown
# funk
#
# Бурёнка Даша
# detskie pesni
#
# Yolka
# russian dance pop
#
# Gogol Bordello
# gypsy punk
#
# deadmau5
# canadian electronic
#
# The Kills
# alternative dance
#
# Midnight Star
# disco

# %%
genre_df.drop_duplicates('genre')
genre_df
# Out:
#                      artist                  genre
# 0                  Bee Gees        adult standards
# 1             Fleetwood Mac             album rock
# 2                Viernes 13           chicano punk
# 3                      GRiZ                    edm
# 4                Atmosphere    alternative hip hop
# 5          Sturgill Simpson  alternative americana
# 6                     Queen           classic rock
# 7             Guns N' Roses             glam metal
# 8              Dove Cameron          post-teen pop
# 9                Asher Roth          indie pop rap
# 10                   Zoogma               jam band
# 11              Brasstracks        alternative r&b
# 12  Eliza & The Delusionals  australian indie rock
# 13                  Wheatus               pop rock
# 14            Umberto Tozzi    classic italian pop
# 15     They Might Be Giants       alternative rock
# 16                     Cake       alternative rock
# 17               Goldfinger               pop punk
# 18               Goldfinger               pop punk
# 19    Fruition & Grant Farm               jamgrass
# 20    Fruition & Grant Farm               jamgrass
# 21               Rapidgrass               jamgrass
# 22            Beats Antique            belly dance
# 23            Beats Antique            belly dance
# 24                GRiZMATiK            livetronica
# 25         Sturgill Simpson  alternative americana
# 26                 Ice Cube      conscious hip hop
# 27        The White Stripes       alternative rock
# 28        The White Stripes       alternative rock
# 29              James Brown                   funk
# 30             Бурёнка Даша          detskie pesni
# 31                    Yolka      russian dance pop
# 32           Gogol Bordello             gypsy punk
# 33                 deadmau5    canadian electronic
# 34                The Kills      alternative dance
# 35            Midnight Star                  disco

# %%
genre_df = pd.DataFrame(genre_df)
genre_df.drop_duplicates()
# Out:
#                      artist                  genre
# 0                  Bee Gees        adult standards
# 1             Fleetwood Mac             album rock
# 2                Viernes 13           chicano punk
# 3                      GRiZ                    edm
# 4                Atmosphere    alternative hip hop
# 5          Sturgill Simpson  alternative americana
# 6                     Queen           classic rock
# 7             Guns N' Roses             glam metal
# 8              Dove Cameron          post-teen pop
# 9                Asher Roth          indie pop rap
# 10                   Zoogma               jam band
# 11              Brasstracks        alternative r&b
# 12  Eliza & The Delusionals  australian indie rock
# 13                  Wheatus               pop rock
# 14            Umberto Tozzi    classic italian pop
# 15     They Might Be Giants       alternative rock
# 16                     Cake       alternative rock
# 17               Goldfinger               pop punk
# 19    Fruition & Grant Farm               jamgrass
# 21               Rapidgrass               jamgrass
# 22            Beats Antique            belly dance
# 24                GRiZMATiK            livetronica
# 26                 Ice Cube      conscious hip hop
# 27        The White Stripes       alternative rock
# 29              James Brown                   funk
# 30             Бурёнка Даша          detskie pesni
# 31                    Yolka      russian dance pop
# 32           Gogol Bordello             gypsy punk
# 33                 deadmau5    canadian electronic
# 34                The Kills      alternative dance
# 35            Midnight Star                  disco

# %%
#Put Track IDs into a list for For Loop

song_id_list = tracks_df["id"].tolist()
# pprint(song_id_list)

# %%
def getTrackFeatures(id):
    meta = sp.track(id)
    features = sp.audio_features(id)

# meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']

# features
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']

    track = [id, name, album, artist, release_date, length, popularity, danceability, acousticness, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
    return track

# %%
# loop over track ids 
tracks = []
for i in range(len(song_id_list)):
    time.sleep(.1)
    track = getTrackFeatures(song_id_list[i])
    tracks.append(track)

# pprint(tracks)

# create dataset
song_data = pd.DataFrame(tracks, columns = ['id','name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e4130a9306ce> in <module>
#       1 # loop over track ids
#       2 tracks = []
# ----> 3 for i in range(len(song_id_list)):
#       4     time.sleep(.1)
#       5     track = getTrackFeatures(song_id_list[i])
#
# NameError: name 'song_id_list' is not defined

# %%
song_data
# Out:
#                          id  \
# 0    2cX2coZS1PYBfPs8wgbdWE
# 1    0ofHAoxe9vBkTCp2UQIavz
# 2    1tzcIjBCwsn4P7D0OsBiFi
# 3    1y4jsQt7MjnZhiD1L6qFBC
# 4    34xLCJSfCdBPcPxZTRezwS
# ..                      ...
# 157  3DofXqoNWqAnzNpSXtSp4R
# 158  4yKZACkuudvfd600H2dQie
# 159  1m3BAsNsQAaSNMD2M6vlKY
# 160  5lYpHO6ZO4Shys3GD8rav6
# 161  3JLcx6VISiIx3Y30XPQ4K9
#
#                                                   name  \
# 0    More Than A Woman - From "Saturday Night Fever...
# 1                               Dreams - 2004 Remaster
# 2                                        The Lucky One
# 3                                              Cradles
# 4                                Dancing Is What to Do
# ..                                                 ...
# 157                                         Murdermile
# 158                                     Get Down On It
# 159                                           Breezin'
# 160                         Whatcha See Is Whatcha Get
# 161        No Parking (On the Dance Floor) - Radio Mix
#
#                                           album           artist release_date  \
# 0               How Can You Mend A Broken Heart         Bee Gees   2020-11-20
# 1                        Rumours (Super Deluxe)    Fleetwood Mac   1977-02-04
# 2                                Thirteen Rules       Viernes 13   2015-01-13
# 3                                       Cradles        Sub Urban   2019-01-04
# 4                         Dancing Is What to Do            Ray-X   2019-05-21
# ..                                          ...              ...          ...
# 157                                      No Wow        The Kills   2005-02-19
# 158  The Very Best Of Kool & The Gang (Reissue)  Kool & The Gang   1999-03-01
# 159                                    Breezin'    George Benson         1976
# 160              The Very Best Of The Dramatics    The Dramatics   2007-01-01
# 161               No Parking on the Dance Floor    Midnight Star   1983-01-01
#
#      length  popularity  danceability  acousticness  energy  instrumentalness  \
# 0    196213          67         0.601        0.1750   0.703          0.000084
# 1    257800          85         0.828        0.0644   0.492          0.004280
# 2    267626          16         0.356        0.0490   0.724          0.000037
# 3    209829          74         0.534        0.2560   0.589          0.000060
# 4    257071          52         0.882        0.2090   0.741          0.000000
# ..      ...         ...           ...           ...     ...               ...
# 157  265306          24         0.760        0.3690   0.847          0.139000
# 158  212906          72         0.879        0.2050   0.626          0.000061
# 159  341733          59         0.682        0.4760   0.752          0.863000
# 160  214973          54         0.641        0.2490   0.740          0.000000
# 161  268640          30         0.933        0.0130   0.788          0.000138
#
#      liveness  loudness  speechiness    tempo  time_signature
# 0      0.5710    -6.240       0.0379  106.164               4
# 1      0.1280    -9.744       0.0276  120.151               4
# 2      0.2710    -5.706       0.0378  163.452               4
# 3      0.1760    -1.865       0.3250   78.616               4
# 4      0.0871    -6.504       0.0383  119.995               4
# ..        ...       ...          ...      ...             ...
# 157    0.0777    -5.589       0.0428  144.116               4
# 158    0.0560    -6.344       0.0604  110.864               4
# 159    0.0768    -9.521       0.0454   81.081               4
# 160    0.2810    -8.425       0.1180  152.939               4
# 161    0.0727    -7.530       0.0565  125.149               4
#
# [162 rows x 16 columns]

# %%
final = pd.merge(song_data, user_song_ids, how = 'left', on = 'id')
final =pd.DataFrame(final)

# %%
final = pd.merge(final, genre_df, how = 'left', left_on = 'artist', right_on = 'artist')

# %%
final
# Out:
#                          id  \
# 0    2cX2coZS1PYBfPs8wgbdWE
# 1    0ofHAoxe9vBkTCp2UQIavz
# 2    1tzcIjBCwsn4P7D0OsBiFi
# 3    1y4jsQt7MjnZhiD1L6qFBC
# 4    34xLCJSfCdBPcPxZTRezwS
# ..                      ...
# 157  3DofXqoNWqAnzNpSXtSp4R
# 158  4yKZACkuudvfd600H2dQie
# 159  1m3BAsNsQAaSNMD2M6vlKY
# 160  5lYpHO6ZO4Shys3GD8rav6
# 161  3JLcx6VISiIx3Y30XPQ4K9
#
#                                                   name  \
# 0    More Than A Woman - From "Saturday Night Fever...
# 1                               Dreams - 2004 Remaster
# 2                                        The Lucky One
# 3                                              Cradles
# 4                                Dancing Is What to Do
# ..                                                 ...
# 157                                         Murdermile
# 158                                     Get Down On It
# 159                                           Breezin'
# 160                         Whatcha See Is Whatcha Get
# 161        No Parking (On the Dance Floor) - Radio Mix
#
#                                           album           artist release_date  \
# 0               How Can You Mend A Broken Heart         Bee Gees   2020-11-20
# 1                        Rumours (Super Deluxe)    Fleetwood Mac   1977-02-04
# 2                                Thirteen Rules       Viernes 13   2015-01-13
# 3                                       Cradles        Sub Urban   2019-01-04
# 4                         Dancing Is What to Do            Ray-X   2019-05-21
# ..                                          ...              ...          ...
# 157                                      No Wow        The Kills   2005-02-19
# 158  The Very Best Of Kool & The Gang (Reissue)  Kool & The Gang   1999-03-01
# 159                                    Breezin'    George Benson         1976
# 160              The Very Best Of The Dramatics    The Dramatics   2007-01-01
# 161               No Parking on the Dance Floor    Midnight Star   1983-01-01
#
#      length  popularity  danceability  acousticness  energy  instrumentalness  \
# 0    196213          67         0.601        0.1750   0.703          0.000084
# 1    257800          85         0.828        0.0644   0.492          0.004280
# 2    267626          16         0.356        0.0490   0.724          0.000037
# 3    209829          74         0.534        0.2560   0.589          0.000060
# 4    257071          52         0.882        0.2090   0.741          0.000000
# ..      ...         ...           ...           ...     ...               ...
# 157  265306          24         0.760        0.3690   0.847          0.139000
# 158  212906          72         0.879        0.2050   0.626          0.000061
# 159  341733          59         0.682        0.4760   0.752          0.863000
# 160  214973          54         0.641        0.2490   0.740          0.000000
# 161  268640          30         0.933        0.0130   0.788          0.000138
#
#      liveness  loudness  speechiness    tempo  time_signature     user_id
# 0      0.5710    -6.240       0.0379  106.164               4  1221063701
# 1      0.1280    -9.744       0.0276  120.151               4  1221063701
# 2      0.2710    -5.706       0.0378  163.452               4  1221063701
# 3      0.1760    -1.865       0.3250   78.616               4  1213961138
# 4      0.0871    -6.504       0.0383  119.995               4  1213961138
# ..        ...       ...          ...      ...             ...         ...
# 157    0.0777    -5.589       0.0428  144.116               4  1221063701
# 158    0.0560    -6.344       0.0604  110.864               4  kukulski.2
# 159    0.0768    -9.521       0.0454   81.081               4  kukulski.2
# 160    0.2810    -8.425       0.1180  152.939               4  kukulski.2
# 161    0.0727    -7.530       0.0565  125.149               4  1221063701
#
# [162 rows x 17 columns]

# %%
final.to_csv("user_song_info.csv", sep = ',')

# %%
tracks_list = []

for index, row in final.iterrows():
    track = {
        'info': {
            'name': row['name'],
            'album': row['album'],
            'artist': row['artist'],
            'user_id': row['user_id']
        },
        'features': {
            'length': row['length'],
            'popularity': row['popularity'],
            'danceability': row['danceability'],
            'acousticness': row['acousticness'],
            'danceability': row['danceability'],
            'energy': row['energy'],
            'instrumentalness': row['instrumentalness'],
            'liveness': row['liveness'],
            'loudness': row['loudness'],
            'speechiness': row['speechiness'],
            'tempo': row['tempo'],
            'time_signature': row['time_signature'],
        }
    }
    tracks_list.append(track)

# %%
from pymongo import MongoClient
import dns
mdb_connect_string = "mongodb+srv://spotify_user:dubootcamp@spotify-project.xeewg.mongodb.net/<dbname>?retryWrites=true&w=majority"

# %%
connection = MongoClient(mdb_connect_string)

# %%
db = connection.spotify

# %%
mdb_playlist = db.playlists.find_one()

# %%
mdb_playlist['snapshot_id']
# Out:
# 'abc123'

# %%
playlist['snapshot_id']
# Out:
# 'MTgyLGQ4ZThlYzMxMGM4NDExMWY5YTc3MjA3ZTk1YTU1NDU3N2M5YWUzNjA='

# %%
db.playlists.update({}, playlist, upsert=True)
# Out:
# <ipython-input-12-9125eab5d67e>:1: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   db.playlists.update({}, playlist, upsert=True)
# {'n': 1,
#  'nModified': 1,
#  'opTime': {'ts': Timestamp(1612833752, 1), 't': 23},
#  'electionId': ObjectId('7fffffff0000000000000017'),
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1612833752, 1),
#   'signature': {'hash': b'\x17\xd5\x19v\x85\xa9\xe1Lf\xa29\x18S)\xfe[dM|v',
#    'keyId': 6880974049883717634}},
#  'operationTime': Timestamp(1612833752, 1),
#  'updatedExisting': True}

# %%
db.tracks.drop()
db.tracks.insert_many(tracks_list)

# %%
# Out:
#   File "<ipython-input-15-c7ef0b69fce2>", line 7
#     'danceability': danceability    0.601
#                                     ^
# SyntaxError: invalid syntax
